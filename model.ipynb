# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import numpy as np

# %%
input_cols = [
#     'ANGER', 'CONTEMPT', 'DISGUST', 'FEAR', 'HAPPINESS', 'NEUTRAL', 'SADNESS', 'SURPRISE', 
    'ValenceMean-IAPS', 'ArousalMean-IAPS', 'ValenceMean_IADS', 'ArousalMean_IADS', 
    'ANS-TIME', 'EMO-ANS', 'VALENCE-ANS', 'AROUSAL-ANS'
]
output_cols = [
#     'EXTRAVERSION',"OPENNESS","CONSCIENTIOUSNESS","AGREEABLENESS","NEUROTICISM" 
]

dataset = pd.read_csv("preprocessed/ALL-DATA.csv")

data = dataset[input_cols]

data.describe()
# Out:
#        ValenceMean-IAPS  ArousalMean-IAPS  ValenceMean_IADS  ArousalMean_IADS  \
# count      17709.000000      17709.000000      17709.000000      17709.000000
# mean           4.564202          6.022095          4.903490          6.373551
# std            2.176713          0.810646          1.935859          0.887747
# min            1.310000          3.770000          1.630000          3.930000
# 25%            2.470000          5.670000          3.050000          5.890000
# 50%            4.480000          6.210000          5.150000          6.480000
# 75%            6.730000          6.580000          6.770000          6.980000
# max            7.770000          7.350000          7.900000          7.990000
#
#            ANS-TIME      EMO-ANS   VALENCE-ANS   AROUSAL-ANS
# count  17709.000000  17709.00000  17709.000000  17709.000000
# mean      15.387507      1.38184     -0.055978      0.034314
# std       33.092150      1.62211      0.371861      0.331234
# min        0.000186      0.00000     -1.000000     -1.000000
# 25%        0.766920      0.00000     -0.029970      0.000000
# 50%        2.235797      1.00000      0.000000      0.000000
# 75%        5.305965      3.00000      0.000000      0.025472
# max      100.000000      5.00000      1.000000      1.000000

# %%
scaler_x = preprocessing.MinMaxScaler()
xscale = scaler_x.fit_transform(data)

# %%
data.hist()
plt.savefig("histogram.png")

# %%
from sklearn.preprocessing import minmax_scale

all_columns = input_cols.copy()
all_columns.extend(output_cols)

print(input_cols)

dataset_2 = dataset[all_columns]


scaler = preprocessing.MinMaxScaler()

normalized = scaler.fit_transform(dataset_2[dataset_2.columns].values)

data_scaled = pd.DataFrame(normalized, columns=all_columns)

# dataset_2_scaled = scaler_x.fit_transform(dataset_2)
dataset_2.head(20)
# Out:
# ['ValenceMean-IAPS', 'ArousalMean-IAPS', 'ValenceMean_IADS', 'ArousalMean_IADS', 'ANS-TIME', 'EMO-ANS', 'VALENCE-ANS', 'AROUSAL-ANS']
#     ValenceMean-IAPS  ArousalMean-IAPS  ValenceMean_IADS  ArousalMean_IADS  \
# 0               4.31              4.47              4.96              5.37
# 1               2.91              5.86              3.37              6.39
# 2               7.38              6.28              3.37              6.39
# 3               1.82              5.75              6.40              5.64
# 4               2.91              5.86              7.64              6.03
# 5               7.56              5.74              7.64              6.03
# 6               4.59              4.42              5.20              5.41
# 7               4.05              4.38              4.64              4.93
# 8               5.24              3.97              5.64              4.77
# 9               7.40              6.58              3.55              6.98
# 10              2.95              5.91              3.55              6.98
# 11              4.67              4.68              5.23              5.51
# 12              4.71              4.60              5.31              4.60
# 13              6.22              6.62              6.31              7.10
# 14              6.44              7.07              6.70              7.31
# 15              2.10              6.53              6.70              7.31
# 16              6.67              7.13              6.81              7.13
# 17              2.33              6.00              6.81              7.13
# 18              1.31              6.91              5.68              6.82
# 19              6.43              5.79              6.47              6.46
#
#       ANS-TIME  EMO-ANS  VALENCE-ANS  AROUSAL-ANS
# 0     1.184649      1.0     0.000000     0.000000
# 1     1.718510      2.0     0.000000     0.000000
# 2     1.785309      0.0     0.483333     0.163721
# 3     2.653014      0.0    -0.995714     0.180954
# 4     0.033457      4.0     0.000000     0.000000
# 5     0.217014      4.0     0.000000     0.000000
# 6     0.317123      4.0     0.000000     0.000000
# 7     0.167422      1.0     0.000000     0.000000
# 8     0.600789      0.0    -0.033442    -0.190947
# 9     0.934360      4.0     0.000000     0.000000
# 10  100.000000      3.0     0.000000     0.000000
# 11  100.000000      3.0     0.000000     0.000000
# 12    4.654852      2.0     0.000000     0.000000
# 13    0.066882      4.0     0.000000     0.000000
# 14    2.769680      0.0     0.399832     0.438916
# 15  100.000000      3.0     0.000000     0.000000
# 16    0.517280      4.0     0.000000     0.000000
# 17  100.000000      3.0     0.000000     0.000000
# 18    0.417234      2.0     0.000000     0.000000
# 19  100.000000      3.0     0.000000     0.000000

# %%
data_scaled.head(20)
# Out:
#     ValenceMean-IAPS  ArousalMean-IAPS  ValenceMean_IADS  ArousalMean_IADS  \
# 0           0.464396          0.195531          0.531100          0.354680
# 1           0.247678          0.583799          0.277512          0.605911
# 2           0.939628          0.701117          0.277512          0.605911
# 3           0.078947          0.553073          0.760766          0.421182
# 4           0.247678          0.583799          0.958533          0.517241
# 5           0.967492          0.550279          0.958533          0.517241
# 6           0.507740          0.181564          0.569378          0.364532
# 7           0.424149          0.170391          0.480064          0.246305
# 8           0.608359          0.055866          0.639553          0.206897
# 9           0.942724          0.784916          0.306220          0.751232
# 10          0.253870          0.597765          0.306220          0.751232
# 11          0.520124          0.254190          0.574163          0.389163
# 12          0.526316          0.231844          0.586922          0.165025
# 13          0.760062          0.796089          0.746411          0.780788
# 14          0.794118          0.921788          0.808612          0.832512
# 15          0.122291          0.770950          0.808612          0.832512
# 16          0.829721          0.938547          0.826156          0.788177
# 17          0.157895          0.622905          0.826156          0.788177
# 18          0.000000          0.877095          0.645933          0.711823
# 19          0.792570          0.564246          0.771930          0.623153
#
#     ANS-TIME  EMO-ANS  VALENCE-ANS  AROUSAL-ANS
# 0   0.011845      0.2     0.500000     0.500000
# 1   0.017183      0.4     0.500000     0.500000
# 2   0.017851      0.0     0.741666     0.581861
# 3   0.026528      0.0     0.002143     0.590477
# 4   0.000333      0.8     0.500000     0.500000
# 5   0.002168      0.8     0.500000     0.500000
# 6   0.003169      0.8     0.500000     0.500000
# 7   0.001672      0.2     0.500000     0.500000
# 8   0.006006      0.0     0.483279     0.404526
# 9   0.009342      0.8     0.500000     0.500000
# 10  1.000000      0.6     0.500000     0.500000
# 11  1.000000      0.6     0.500000     0.500000
# 12  0.046547      0.4     0.500000     0.500000
# 13  0.000667      0.8     0.500000     0.500000
# 14  0.027695      0.0     0.699916     0.719458
# 15  1.000000      0.6     0.500000     0.500000
# 16  0.005171      0.8     0.500000     0.500000
# 17  1.000000      0.6     0.500000     0.500000
# 18  0.004170      0.4     0.500000     0.500000
# 19  1.000000      0.6     0.500000     0.500000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = data_scaled.corr()
plt.figure(figsize=(10,8))
ax = sns.heatmap(correlation_matrix, vmax=1, square=True, annot=True,fmt='.2f', cmap ='GnBu', cbar_kws={"shrink": .5}, robust=True)
plt.title('Correlation matrix between the features', fontsize=20)
plt.show()

# %%
correlations = dataset_2.corr()
# plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,17,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(dataset_2.columns)
ax.set_yticklabels(dataset_2.columns)
plt.xticks(rotation=90)
plt.show()
